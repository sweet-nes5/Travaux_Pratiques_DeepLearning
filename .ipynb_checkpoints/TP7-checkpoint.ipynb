# %% [markdown]
# ## Exercice 1

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Subset
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import torch.nn.functional as F

root_dir = '/home/nesrine/Bureau/DeepLearning/cifar10_data'

#training data
train_data = datasets.CIFAR10(
    root=root_dir, 
    train=True, # we specify train = true to indicate that it is a training a set
    transform=transforms.ToTensor(),
    download=True)
#validation/test data
validation_data = datasets.CIFAR10(
    root=root_dir, 
    train=False, #and here it is a testing set
    transform=transforms.ToTensor(),
    download=True)

labels_dict ={
    0: "plane",
    1: "car",
    2: "bird",
    3: "cat",
    4: "deer",
    5: "dog",
    6: "frog",
    7: "horse",
    8: "ship",
    9: "truck"
}
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# Affichage des cinq premières images avec leurs étiquettes
for i in range(5):
    image, label = train_data[i]
    print(f"Image{i+1} :")
    print("Shape :",image.shape)
    plt.imshow(image.permute(1, 2, 0))
    plt.title(labels_dict[label])
    plt.axis('on')
    plt.show()
# Out:
# Image1 :
# Shape : torch.Size([3, 32, 32])
# Image2 :
# Shape : torch.Size([3, 32, 32])
# Image3 :
# Shape : torch.Size([3, 32, 32])
# Image4 :
# Shape : torch.Size([3, 32, 32])
# Image5 :
# Shape : torch.Size([3, 32, 32])

# %% [markdown]
# ## Exercice 2

# %%
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, kernel_size=(5,5))
        self.conv2 = nn.Conv2d(6, 16, kernel_size=(5,5))
        self.conv3 = nn.Conv2d(16, 120, kernel_size=(5,5))
        self.fc1 = nn.Linear(120,84)
        self.fc2 = nn.Linear(84,10)

    def forward(self,input):
        layer1 = F.relu(self.conv1(input))
        layer2 = F.max_pool2d(layer1, kernel_size=(2,2), stride=2)
        layer3 = F.relu(self.conv2(layer2))
        layer4 = F.max_pool2d(layer3, kernel_size=(2,2), stride=2)
        layer5 = F.relu(self.conv3(layer4))
        layer6 = F.relu(self.fc1(torch.flatten(layer5,1)))
        layer7 = self.fc2(layer6)
        return layer7


model = LeNet5()
num_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print("Number of parameters in model:", num_params)
# Out:
# Number of parameters in model: 62006

# %% [markdown]
# ## Exercice 3

# %%
def compute_accuracy(outputs, labels):
    _, predicted = torch.max(outputs, 1)
    total = labels.size(0)
    correct = (predicted == labels).sum().item()
    accuracy = correct / total
    return accuracy * 100

# Plot monitoring
def ith(l, i):
    return [x[i] for x in l]

def plot_history(h):
    fig, axs = plt.subplots(1, 2)
    axs[0].plot(ith(h,0), ith(h,1))
    axs[0].plot(ith(h,0), ith(h,3), color='red')
    axs[0].set_xlabel('epochs')
    axs[0].set_ylabel('loss')
    axs[1].plot(ith(h,0), ith(h,2))
    axs[1].plot(ith(h,0), ith(h,4), color='red')
    axs[1].set_xlabel('epochs')
    axs[1].set_ylabel('accuracy')
    fig.suptitle('Monitor learning')
    fig.tight_layout()
    plt.show()

# subset des données
train_subset = Subset(train_data, range(500))
validation_subset = Subset(validation_data, range(500))

# training and validation loaders for mini batch
train_loader = DataLoader(train_subset, batch_size=256, shuffle=True)
validation_loader = DataLoader(validation_subset, batch_size=256)

# fonction de perte
CEL = nn.CrossEntropyLoss()

def grad_des(epoch, model, optim):
    history = []
    train_inputs = []
    train_labels = []
    valid_inputs = []
    valid_labels = []
    
    for inputs, targets in validation_loader:
        valid_inputs.append(inputs)
        valid_labels.append(targets)
        
        
    for inputs_, guesses_ in train_loader:
            train_inputs.append(inputs_)
            train_labels.append(guesses_)

    
    for ep in range(epoch):
        for inputs, labels in train_loader:
            optim.zero_grad() 
            outputs = model(inputs) 
            loss = CEL(outputs, labels)  
            loss.backward()  
            optim.step()  
            

        if ep % 100 == 0:
            model.eval()  # evaluation mode
            with torch.no_grad():  # pas de gradient tracking
                train_accuracy = compute_accuracy(outputs, labels)
                val_accuracy = compute_accuracy(outputs, labels)
                loss_val = CEL(
                history.append((ep, loss.detach().numpy(), train_accuracy, val_accuracy))
                history.append((ep, err.detach().numpy(), acc, loss_val.detach().numpy(), acc_val))
                print(f"Epoch {ep}: Loss: {loss.item()}, Train Accuracy: {train_accuracy}, Validation Accuracy: {val_accuracy}")
                print(f"Epoch {ep}: Loss: {err.item()} accuracy {acc} number of batch {ep%train_loader.batch_size}")

    return history
optimizer = torch.optim.Adam(model.parameters())
history = grad_des(500, model, optimizer)
# Out:
# Epoch 0: Loss: 3.930371046066284, Train Accuracy: 51.63934426229508, Validation Accuracy: 51.63934426229508
# Epoch 100: Loss: 0.006567306816577911, Train Accuracy: 100.0, Validation Accuracy: 100.0
# Epoch 200: Loss: 0.0048227328807115555, Train Accuracy: 100.0, Validation Accuracy: 100.0
# Epoch 300: Loss: 0.0033913326915353537, Train Accuracy: 100.0, Validation Accuracy: 100.0
# Epoch 400: Loss: 0.002607555827125907, Train Accuracy: 100.0, Validation Accuracy: 100.0

# %% [markdown]
# ## Exercice 4

# %%
plot_history(history)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 plot_history(history)
#
# Cell In[22], line 9, in plot_history(history)
#       7 axs[0].legend()
#       8 axs[1].plot([x[0] for x in history], [x[2] for x in history], label='Training Accuracy')
# ----> 9 axs[1].plot([x[0] for x in history], [x[4] for x in history], color='red', label='Validation Accuracy')
#      10 axs[1].set_xlabel('Epochs')
#      11 axs[1].set_ylabel('Accuracy')
#
# Cell In[22], line 9, in <listcomp>(.0)
#       7 axs[0].legend()
#       8 axs[1].plot([x[0] for x in history], [x[2] for x in history], label='Training Accuracy')
# ----> 9 axs[1].plot([x[0] for x in history], [x[4] for x in history], color='red', label='Validation Accuracy')
#      10 axs[1].set_xlabel('Epochs')
#      11 axs[1].set_ylabel('Accuracy')
#
# IndexError: tuple index out of range
